# %%
import matplotlib.pyplot as plt
import numpy as np   

x_data = np.loadtxt("data.txt", skiprows=0, dtype='str')
print(x_data)
print(x_data[0])

plt.plot(x_data)
# Out:
# ['-507' '-512' '-512' '-512' '-512' '-503' '-444' '-414' '-382' '-351'
#  '-323' '-301' '-275' '-260' '-236' '-212' '-192' '-172' '-158' '-133'
#  '-121' '-117' '-100' '-86' '-67' '-49' '-35' '-28' '-22' '-17' '-17'
#  '-25' '-28' '-29' '-29' '-30' '-32' '-35' '-45' '-59' '-75' '-89' '-111'
#  '-133' '-159' '-166' '-166' '-164' '-175' '-178' '-205' '-242' '-281'
#  '-313' '-341' '-357' '-373' '-392' '-407' '-432' '-459' '-486' '-512'
#  '-512' '-512' '-512' '-512' '-512' '-512' '-459' '-426' '-396' '-367'
#  '-338' '-315' '-297' '-284' '-267' '-255' '-240' '-230' '-224' '-202'
#  '-187' '-171' '-155' '-135' '-120' '-102' '-84' '-70' '-57' '-42' '-37'
#  '-25' '-21' '-23' '-23' '-23' '-22']
# -507

# %%
x_array
# Out:
# array(['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '',
#        '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '',
#        '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '',
#        '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '',
#        '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '',
#        '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#       dtype='<U32')

# %%
x
