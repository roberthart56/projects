# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.array([(1,2), (3,4)])
c=np.append(a,[(4,5)],axis = 0 )
a,c,c[:,0]

x=c[:,0]
y=c[:,1]

plt.plot(x,y,'o')

# %%
c[:,1]
# Out:
# array([2, 4, 5])

# %%
b
# Out:
# array([1, 2, 3])
