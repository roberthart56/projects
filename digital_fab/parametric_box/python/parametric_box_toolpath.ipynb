# %%
import numpy as np
import matplotlib.pyplot as plt
import math



def box_path(a,b,h,w,r):
    return np.array([(a-r, b-r), (a+w+r, b-r), (a+w+r, b+h+r), (a-r, b+h+r),(a-r, b-r)])


a=np.append(box_path(0,0,10,15,24.5/2/8),box_path(10,20,10,15,24.5/2/8),axis=0)

#np.append(a,[(11,10)],axis = 0 )
x=a[:,0]
y=a[:,1]


fig = plt.figure(figsize=(10, 10))
fig.clf()
plt.title('box')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,y,'r') 
    
 #plt.plot(rps_1, mean_times_1, 'ro')
    
plt.show()

# %%
import numpy as np

def box_path(a,b,h,w,r):
    return np.array([(a-r, b-r), (a+w+r, b+r), (a+w+r, b+h+r), (a-r, b+h+r)])


f=box_path(0,0,10,15,0)
f
# Out:
# array([[ 0,  0],
#        [15,  0],
#        [15, 10],
#        [ 0, 10]])

# %%
b
# Out:
# array([1, 2, 3])
